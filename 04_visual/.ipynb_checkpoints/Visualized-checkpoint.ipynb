# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import math

# %%
def radar(res):
    for i in range(7):
        #ref https://python-graph-gallery.com/390-basic-radar-chart/
        # number of variable
        categories=list(res.T)
        N = len(categories)

        values=res.iloc[:,i].values.flatten().tolist()
        values += values[:1]


        # What will be the angle of each axis in the plot? (we divide the plot / number of variable)
        angles = [n / float(N) * 2 * math.pi for n in range(N)]
        angles += angles[:1]

        # Initialise the spider plot
        ax = plt.subplot(111, polar=True)

        # Draw one axe per variable + add labels
        plt.xticks(angles[:-1], categories, color='grey', size=9)

        # Draw ylabels
        ax.set_rlabel_position(0)
        plt.yticks([0,0.25,0.5, 0.75, 1], ["0","0.25", "0.5","0.75", "1"], color="grey", size=7)
        plt.ylim(0,1)

        # Plot data
        ax.plot(angles, values, linewidth=1, linestyle='solid', color="grey")

        # Fill area
        ax.fill(angles, values, '#E8C389', alpha=0.3)
        #plt.title("Cluster"+str(i))
        # Show the graph
        
        plt.savefig("Cluster"+str(i)+"radar.png", transparent=True)
        plt.show()

# %%
def mulradar2(res, clusters):
    #ref https://python-graph-gallery.com/391-radar-chart-with-several-individuals/
    # number of variable
    categories=list(res.T)
    N = len(categories)

    values=res.iloc[:,i].values.flatten().tolist()
    values += values[:1]


    # What will be the angle of each axis in the plot? (we divide the plot / number of variable)
    angles = [n / float(N) * 2 * math.pi for n in range(N)]
    angles += angles[:1]

    # Initialise the spider plot
    ax = plt.subplot(111, polar=True)

    # Draw one axe per variable + add labels
    plt.xticks(angles[:-1], categories, color='white', size=8)

    # Draw ylabels
    ax.set_rlabel_position(0)
    plt.yticks([0,0.25,0.5, 0.75, 1], ["0","0.25", "0.5","0.75", "1"], color="white", size=7)
    plt.ylim(0,1)

    # Ind0
    colors = ['orange', 'aqua','orange','aqua', 'orange', 'aqua', 'w' ]
    for k in clusters:
        values=res.iloc[:,k].values.flatten().tolist()
        values += values[:1]
        ax.plot(angles, values, linewidth=1, linestyle='solid', label=res.columns[k][6:],color=colors[k])
        ax.fill(angles, values, colors[k], alpha=0.1)

    
    # Add legend
    #plt.legend(loc='upper right', bbox_to_anchor=(0, 0))

    #plt.title("Compare ranked Cluster "+str(clusters))
    # Show the graph
    plt.savefig("Compare ranked"+str(clusters)+"radar.png", transparent=True)
    plt.show()

# %%
df = pd.read_csv("compare.csv")
df
# Out:
#               V_ID             Town  Cluster_result  \
# 0     65000090-001  Sanxia District               1
# 1     65000090-004  Sanxia District               1
# 2     65000090-025  Sanxia District               1
# 3     65000090-026  Sanxia District               0
# 4     65000090-014  Sanxia District               0
# ...            ...              ...             ...
# 1483  63000070-025  Wanhua District               1
# 1484  63000070-012  Wanhua District               3
# 1485  63000070-006  Wanhua District               4
# 1486  63000070-011  Wanhua District               3
# 1487  63000070-036  Wanhua District               1
#
#                                       Cluster_name  QoL_Score  Marital status  \
# 0                    Suburb: Small Town Settlement      79.57        0.006479
# 1                    Suburb: Small Town Settlement      72.45        0.108768
# 2                    Suburb: Small Town Settlement      48.59        0.152930
# 3                      Suburb: Remote and Desolate       8.27        0.112955
# 4                      Suburb: Remote and Desolate      11.96        0.027728
# ...                                            ...        ...             ...
# 1483                 Suburb: Small Town Settlement      48.99        0.155362
# 1484                                   City Center      70.50        0.135148
# 1485  Close to Downtown: Convenient Transportation      67.74        0.158483
# 1486                                   City Center      47.04        0.188129
# 1487                 Suburb: Small Town Settlement      77.35        0.096858
#
#       Population Density  Natural Increase  Social Increase  Housing Price  \
# 0               0.078739          0.163000         0.113749       0.193649
# 1               0.039914          0.190574         0.127951       0.193649
# 2               0.043728          0.179715         0.111903       0.193649
# 3               0.015230          0.178285         0.111110       0.193649
# 4               0.000504          0.140115         0.113066       0.193649
# ...                  ...               ...              ...            ...
# 1483            0.236451          0.154633         0.105859       0.334884
# 1484            0.193873          0.152897         0.106305       0.334884
# 1485            0.127259          0.126143         0.113523       0.334884
# 1486            0.256663          0.166206         0.097829       0.334884
# 1487            0.047959          0.163000         0.110139       0.334884
#
#       ...  Metro in 300m  Multi Metro in 300m  Metro in 500m  \
# 0     ...              0                    0              0
# 1     ...              0                    0              0
# 2     ...              0                    0              0
# 3     ...              0                    0              0
# 4     ...              0                    0              0
# ...   ...            ...                  ...            ...
# 1483  ...              0                    0              0
# 1484  ...              1                    0              1
# 1485  ...              1                    0              1
# 1486  ...              1                    0              1
# 1487  ...              0                    0              0
#
#       Multi Metro in 500m  Primary School  High School  Gym  Fire station  \
# 0                       0               1            1    0             1
# 1                       0               1            1    0             1
# 2                       0               1            1    0             1
# 3                       0               0            0    0             0
# 4                       0               0            0    0             0
# ...                   ...             ...          ...  ...           ...
# 1483                    0               1            1    0             1
# 1484                    0               1            1    0             1
# 1485                    0               1            0    0             1
# 1486                    0               1            1    0             1
# 1487                    0               1            1    0             1
#
#       Police station   Shelter
# 0                  1  0.000000
# 1                  1  0.003876
# 2                  1  0.003876
# 3                  1  0.000000
# 4                  1  0.003876
# ...              ...       ...
# 1483               1  0.139535
# 1484               1  0.306202
# 1485               1  0.465116
# 1486               1  0.379845
# 1487               1  0.046512
#
# [1488 rows x 29 columns]

# %%
keep = []
count = []
col = []
for i in range(7):
    df1 = df[df['Cluster_result']==i]
    keep.append(df1.describe().iloc[1,1:])
    keep.append(df1.describe().iloc[2,1:])
    count.append(df1.describe().iloc[0,0])
    count.append(df1.describe().iloc[0,0])
    col.append('Mean '+ str(i)+df['Cluster_name'][df['Cluster_result']==i].unique()[0])
    col.append('Std '+ str(i)+df['Cluster_name'][df['Cluster_result']==i].unique()[0])
    
trans = pd.DataFrame(keep, index=col)
trans['Count'] = count
trans =trans.sort_index(ascending=True)
trans
# Out:
#                                                     QoL_Score  Marital status  \
# Mean 0Suburb: Remote and Desolate                   19.953882        0.080634
# Mean 1Suburb: Small Town Settlement                 50.304053        0.123046
# Mean 2Outskirt: Influx of New Residents             28.700455        0.099103
# Mean 3City Center                                   73.348296        0.146582
# Mean 4Close to Downtown: Convenient Transportation  81.048258        0.159844
# Mean 5Outskirt: High Population Density, Old Town   34.960667        0.124807
# Mean 6Downtown: New Taipei City                     39.152857        0.124718
# Std 0Suburb: Remote and Desolate                    13.876843        0.063077
# Std 1Suburb: Small Town Settlement                  19.754315        0.062772
# Std 2Outskirt: Influx of New Residents              18.830500        0.046667
# Std 3City Center                                    18.187101        0.036895
# Std 4Close to Downtown: Convenient Transportation   15.737176        0.050694
# Std 5Outskirt: High Population Density, Old Town    19.381388        0.044679
# Std 6Downtown: New Taipei City                      28.622998        0.043585
#
#                                                     Population Density  \
# Mean 0Suburb: Remote and Desolate                             0.047947
# Mean 1Suburb: Small Town Settlement                           0.124185
# Mean 2Outskirt: Influx of New Residents                       0.241477
# Mean 3City Center                                             0.233231
# Mean 4Close to Downtown: Convenient Transportation            0.153755
# Mean 5Outskirt: High Population Density, Old Town             0.268134
# Mean 6Downtown: New Taipei City                               0.245931
# Std 0Suburb: Remote and Desolate                              0.086765
# Std 1Suburb: Small Town Settlement                            0.114650
# Std 2Outskirt: Influx of New Residents                        0.089321
# Std 3City Center                                              0.067615
# Std 4Close to Downtown: Convenient Transportation             0.091061
# Std 5Outskirt: High Population Density, Old Town              0.074935
# Std 6Downtown: New Taipei City                                0.085172
#
#                                                     Natural Increase  \
# Mean 0Suburb: Remote and Desolate                           0.161261
# Mean 1Suburb: Small Town Settlement                         0.169510
# Mean 2Outskirt: Influx of New Residents                     0.162057
# Mean 3City Center                                           0.167228
# Mean 4Close to Downtown: Convenient Transportation          0.173361
# Mean 5Outskirt: High Population Density, Old Town           0.165703
# Mean 6Downtown: New Taipei City                             0.169308
# Std 0Suburb: Remote and Desolate                            0.017298
# Std 1Suburb: Small Town Settlement                          0.022597
# Std 2Outskirt: Influx of New Residents                      0.021271
# Std 3City Center                                            0.019634
# Std 4Close to Downtown: Convenient Transportation           0.025907
# Std 5Outskirt: High Population Density, Old Town            0.017965
# Std 6Downtown: New Taipei City                              0.023742
#
#                                                     Social Increase  \
# Mean 0Suburb: Remote and Desolate                          0.112252
# Mean 1Suburb: Small Town Settlement                        0.111611
# Mean 2Outskirt: Influx of New Residents                    0.112392
# Mean 3City Center                                          0.105590
# Mean 4Close to Downtown: Convenient Transportation         0.108022
# Mean 5Outskirt: High Population Density, Old Town          0.111466
# Mean 6Downtown: New Taipei City                            0.111810
# Std 0Suburb: Remote and Desolate                           0.004661
# Std 1Suburb: Small Town Settlement                         0.007898
# Std 2Outskirt: Influx of New Residents                     0.003939
# Std 3City Center                                           0.011225
# Std 4Close to Downtown: Convenient Transportation          0.011068
# Std 5Outskirt: High Population Density, Old Town           0.004933
# Std 6Downtown: New Taipei City                             0.005587
#
#                                                     Housing Price    Income  \
# Mean 0Suburb: Remote and Desolate                        0.195234  0.034073
# Mean 1Suburb: Small Town Settlement                      0.230097  0.053267
# Mean 2Outskirt: Influx of New Residents                  0.271885  0.041607
# Mean 3City Center                                        0.396434  0.085636
# Mean 4Close to Downtown: Convenient Transportation       0.350282  0.088601
# Mean 5Outskirt: High Population Density, Old Town        0.280273  0.058542
# Mean 6Downtown: New Taipei City                          0.275981  0.056436
# Std 0Suburb: Remote and Desolate                         0.103256  0.033003
# Std 1Suburb: Small Town Settlement                       0.095553  0.031303
# Std 2Outskirt: Influx of New Residents                   0.003089  0.022919
# Std 3City Center                                         0.076491  0.024009
# Std 4Close to Downtown: Convenient Transportation        0.094307  0.029402
# Std 5Outskirt: High Population Density, Old Town         0.044741  0.022276
# Std 6Downtown: New Taipei City                           0.011087  0.023093
#
#                                                         edu1      edu2  \
# Mean 0Suburb: Remote and Desolate                   0.078377  0.461637
# Mean 1Suburb: Small Town Settlement                 0.121644  0.502817
# Mean 2Outskirt: Influx of New Residents             0.097456  0.492002
# Mean 3City Center                                   0.150298  0.367809
# Mean 4Close to Downtown: Convenient Transportation  0.162690  0.385604
# Mean 5Outskirt: High Population Density, Old Town   0.126129  0.473039
# Mean 6Downtown: New Taipei City                     0.122099  0.489243
# Std 0Suburb: Remote and Desolate                    0.064693  0.091156
# Std 1Suburb: Small Town Settlement                  0.063295  0.115132
# Std 2Outskirt: Influx of New Residents              0.046215  0.079772
# Std 3City Center                                    0.037910  0.111677
# Std 4Close to Downtown: Convenient Transportation   0.051323  0.124700
# Std 5Outskirt: High Population Density, Old Town    0.044431  0.090761
# Std 6Downtown: New Taipei City                      0.043320  0.083898
#
#                                                          NO2  ...  \
# Mean 0Suburb: Remote and Desolate                   0.113936  ...
# Mean 1Suburb: Small Town Settlement                 0.095871  ...
# Mean 2Outskirt: Influx of New Residents             0.103544  ...
# Mean 3City Center                                   0.107586  ...
# Mean 4Close to Downtown: Convenient Transportation  0.102201  ...
# Mean 5Outskirt: High Population Density, Old Town   0.102453  ...
# Mean 6Downtown: New Taipei City                     0.114605  ...
# Std 0Suburb: Remote and Desolate                    0.036049  ...
# Std 1Suburb: Small Town Settlement                  0.032397  ...
# Std 2Outskirt: Influx of New Residents              0.022754  ...
# Std 3City Center                                    0.028975  ...
# Std 4Close to Downtown: Convenient Transportation   0.028628  ...
# Std 5Outskirt: High Population Density, Old Town    0.022881  ...
# Std 6Downtown: New Taipei City                      0.010485  ...
#
#                                                     Multi Metro in 300m  \
# Mean 0Suburb: Remote and Desolate                              0.000000
# Mean 1Suburb: Small Town Settlement                            0.000000
# Mean 2Outskirt: Influx of New Residents                        0.000000
# Mean 3City Center                                              0.037037
# Mean 4Close to Downtown: Convenient Transportation             0.042042
# Mean 5Outskirt: High Population Density, Old Town              0.000000
# Mean 6Downtown: New Taipei City                                0.071429
# Std 0Suburb: Remote and Desolate                               0.000000
# Std 1Suburb: Small Town Settlement                             0.000000
# Std 2Outskirt: Influx of New Residents                         0.000000
# Std 3City Center                                               0.189556
# Std 4Close to Downtown: Convenient Transportation              0.200987
# Std 5Outskirt: High Population Density, Old Town               0.000000
# Std 6Downtown: New Taipei City                                 0.258567
#
#                                                     Metro in 500m  \
# Mean 0Suburb: Remote and Desolate                        0.037975
# Mean 1Suburb: Small Town Settlement                      0.072000
# Mean 2Outskirt: Influx of New Residents                  0.818182
# Mean 3City Center                                        1.000000
# Mean 4Close to Downtown: Convenient Transportation       1.000000
# Mean 5Outskirt: High Population Density, Old Town        0.586667
# Mean 6Downtown: New Taipei City                          0.634921
# Std 0Suburb: Remote and Desolate                         0.191540
# Std 1Suburb: Small Town Settlement                       0.258833
# Std 2Outskirt: Influx of New Residents                   0.387164
# Std 3City Center                                         0.000000
# Std 4Close to Downtown: Convenient Transportation        0.000000
# Std 5Outskirt: High Population Density, Old Town         0.494081
# Std 6Downtown: New Taipei City                           0.483374
#
#                                                     Multi Metro in 500m  \
# Mean 0Suburb: Remote and Desolate                              0.000000
# Mean 1Suburb: Small Town Settlement                            0.002667
# Mean 2Outskirt: Influx of New Residents                        0.196970
# Mean 3City Center                                              0.370370
# Mean 4Close to Downtown: Convenient Transportation             0.417417
# Mean 5Outskirt: High Population Density, Old Town              0.040000
# Mean 6Downtown: New Taipei City                                0.230159
# Std 0Suburb: Remote and Desolate                               0.000000
# Std 1Suburb: Small Town Settlement                             0.051640
# Std 2Outskirt: Influx of New Residents                         0.399224
# Std 3City Center                                               0.484702
# Std 4Close to Downtown: Convenient Transportation              0.493875
# Std 5Outskirt: High Population Density, Old Town               0.196616
# Std 6Downtown: New Taipei City                                 0.422615
#
#                                                     Primary School  \
# Mean 0Suburb: Remote and Desolate                         0.434599
# Mean 1Suburb: Small Town Settlement                       0.949333
# Mean 2Outskirt: Influx of New Residents                   0.000000
# Mean 3City Center                                         0.940741
# Mean 4Close to Downtown: Convenient Transportation        0.930931
# Mean 5Outskirt: High Population Density, Old Town         0.973333
# Mean 6Downtown: New Taipei City                           0.047619
# Std 0Suburb: Remote and Desolate                          0.496753
# Std 1Suburb: Small Town Settlement                        0.219609
# Std 2Outskirt: Influx of New Residents                    0.000000
# Std 3City Center                                          0.236989
# Std 4Close to Downtown: Convenient Transportation         0.253953
# Std 5Outskirt: High Population Density, Old Town          0.161647
# Std 6Downtown: New Taipei City                            0.213809
#
#                                                     High School       Gym  \
# Mean 0Suburb: Remote and Desolate                      0.109705  0.021097
# Mean 1Suburb: Small Town Settlement                    0.757333  0.101333
# Mean 2Outskirt: Influx of New Residents                0.606061  0.098485
# Mean 3City Center                                      0.829630  0.259259
# Mean 4Close to Downtown: Convenient Transportation     0.684685  0.213213
# Mean 5Outskirt: High Population Density, Old Town      0.726667  0.213333
# Mean 6Downtown: New Taipei City                        0.658730  0.119048
# Std 0Suburb: Remote and Desolate                       0.313183  0.144012
# Std 1Suburb: Small Town Settlement                     0.429268  0.302173
# Std 2Outskirt: Influx of New Residents                 0.490483  0.299104
# Std 3City Center                                       0.377358  0.439860
# Std 4Close to Downtown: Convenient Transportation      0.465341  0.410193
# Std 5Outskirt: High Population Density, Old Town       0.447164  0.411034
# Std 6Downtown: New Taipei City                         0.476029  0.325137
#
#                                                     Fire station  \
# Mean 0Suburb: Remote and Desolate                       0.092827
# Mean 1Suburb: Small Town Settlement                     0.850667
# Mean 2Outskirt: Influx of New Residents                 0.022727
# Mean 3City Center                                       0.970370
# Mean 4Close to Downtown: Convenient Transportation      0.708709
# Mean 5Outskirt: High Population Density, Old Town       0.053333
# Mean 6Downtown: New Taipei City                         0.833333
# Std 0Suburb: Remote and Desolate                        0.290804
# Std 1Suburb: Small Town Settlement                      0.356893
# Std 2Outskirt: Influx of New Residents                  0.149600
# Std 3City Center                                        0.170195
# Std 4Close to Downtown: Convenient Transportation       0.455041
# Std 5Outskirt: High Population Density, Old Town        0.225450
# Std 6Downtown: New Taipei City                          0.374166
#
#                                                     Police station   Shelter  \
# Mean 0Suburb: Remote and Desolate                         0.759494  0.022618
# Mean 1Suburb: Small Town Settlement                       0.994667  0.034605
# Mean 2Outskirt: Influx of New Residents                   0.992424  0.001057
# Mean 3City Center                                         1.000000  0.211140
# Mean 4Close to Downtown: Convenient Transportation        0.990991  0.160893
# Mean 5Outskirt: High Population Density, Old Town         0.993333  0.011602
# Mean 6Downtown: New Taipei City                           0.825397  0.002492
# Std 0Suburb: Remote and Desolate                          0.428295  0.080386
# Std 1Suburb: Small Town Settlement                        0.072932  0.088640
# Std 2Outskirt: Influx of New Residents                    0.087039  0.002399
# Std 3City Center                                          0.000000  0.162264
# Std 4Close to Downtown: Convenient Transportation         0.094629  0.150740
# Std 5Outskirt: High Population Density, Old Town          0.081650  0.050647
# Std 6Downtown: New Taipei City                            0.381143  0.015265
#
#                                                     Count
# Mean 0Suburb: Remote and Desolate                   237.0
# Mean 1Suburb: Small Town Settlement                 375.0
# Mean 2Outskirt: Influx of New Residents             132.0
# Mean 3City Center                                   135.0
# Mean 4Close to Downtown: Convenient Transportation  333.0
# Mean 5Outskirt: High Population Density, Old Town   150.0
# Mean 6Downtown: New Taipei City                     126.0
# Std 0Suburb: Remote and Desolate                    237.0
# Std 1Suburb: Small Town Settlement                  375.0
# Std 2Outskirt: Influx of New Residents              132.0
# Std 3City Center                                    135.0
# Std 4Close to Downtown: Convenient Transportation   333.0
# Std 5Outskirt: High Population Density, Old Town    150.0
# Std 6Downtown: New Taipei City                      126.0
#
# [14 rows x 26 columns]

# %%
trans.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 14 entries, Mean 0Suburb: Remote and Desolate to Std 6Downtown: New Taipei City
# Data columns (total 26 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   QoL_Score            14 non-null     float64
#  1   Marital status       14 non-null     float64
#  2   Population Density   14 non-null     float64
#  3   Natural Increase     14 non-null     float64
#  4   Social Increase      14 non-null     float64
#  5   Housing Price        14 non-null     float64
#  6   Income               14 non-null     float64
#  7   edu1                 14 non-null     float64
#  8   edu2                 14 non-null     float64
#  9   NO2                  14 non-null     float64
#  10  PM2.5                14 non-null     float64
#  11  Hospital             14 non-null     float64
#  12  Water                14 non-null     float64
#  13  Green                14 non-null     float64
#  14  Area                 14 non-null     float64
#  15  Metro in 300m        14 non-null     float64
#  16  Multi Metro in 300m  14 non-null     float64
#  17  Metro in 500m        14 non-null     float64
#  18  Multi Metro in 500m  14 non-null     float64
#  19  Primary School       14 non-null     float64
#  20  High School          14 non-null     float64
#  21  Gym                  14 non-null     float64
#  22  Fire station         14 non-null     float64
#  23  Police station       14 non-null     float64
#  24  Shelter              14 non-null     float64
#  25  Count                14 non-null     float64
# dtypes: float64(26)
# memory usage: 3.0+ KB

# %%
r = trans.iloc[:7,:].rank(ascending=False)
trans[r.columns+'_rank'] = r

# %%
trans.T.to_csv('visul.csv')

# %%
radar(trans.iloc[:,1:25].drop(columns=['edu1', 'edu2']).T)

# %%
mulradar2(trans.iloc[:,1:25].drop(columns=['edu1', 'edu2']).T, [0,1])

# %%
mulradar2(trans.iloc[:,1:25].drop(columns=['edu1', 'edu2']).T, [2,5])

# %%
mulradar2(trans.iloc[:,1:25].drop(columns=['edu1', 'edu2']).T, [3,4,6])

# %%
mulradar2(trans.iloc[:,1:25].drop(columns=['edu1', 'edu2']).T, [0,1])

# %%
mulradar2(trans.iloc[:,1:25].drop(columns=['edu1', 'edu2']).T, [2,5])

# %%
mulradar2(trans.iloc[:,1:25].drop(columns=['edu1', 'edu2']).T, [3,4,6])
